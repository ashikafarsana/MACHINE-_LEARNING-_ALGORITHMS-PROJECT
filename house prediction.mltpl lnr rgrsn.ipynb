# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,confusion_matrix

# %%
dtst=pd.read_csv("C:/Users/PARCHU/Downloads/kc_house_data.csv")

# %%
dtst
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
dtst.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
train,test=train_test_split(dtst,test_size=0.3)
trainx=train.iloc[:,3:21]
trainy=train.iloc[:,2]
testx=test.iloc[:,3:21]
testy=test.iloc[:,2]

# %%
trainx
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 19197         4       2.50         3200      7282     2.0           0     0
# 8108          2       2.00         1960      4018     1.0           0     0
# 16502         2       2.25         1610      1968     2.0           0     0
# 4792          4       2.00         1760      4500     1.5           0     0
# 3276          3       2.25         2090      9163     1.0           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 6652          3       2.75         2370      4632     2.0           0     0
# 1028          3       1.75         1490      6930     1.0           0     0
# 18037         2       0.75          840     40642     1.0           1     4
# 6975          4       2.25         2170      8240     2.0           0     1
# 7794          5       2.50         2720      5000     1.5           0     0
#
# ...

# %%
trainy
# Out:
# 19197    360000.0
# 8108     395000.0
# 16502    305000.0
# 4792     720000.0
# 3276     456500.0
#            ...
# 6652     350000.0
# 1028     245000.0
# 18037    528000.0
# 6975     648000.0
# 7794     580000.0
# Name: price, Length: 15129, dtype: float64

# %%
lr=LinearRegression()
lr.fit(trainx,trainy)
prd=lr.predict(testx)
acc=r2_score(prd,testy)

# %%
#cm=confusion_matrix(prd,testy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10092/3144408583.py in <module>
# ----> 1 cm=confusion_matrix(prd,testy)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     297
#     298     """
# --> 299     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     300     if y_type not in ("binary", "multiclass"):
#     301         raise ValueError("%s is not supported" % y_type)
#
# ...

# %%
acc
# Out:
# 0.513075638500798
