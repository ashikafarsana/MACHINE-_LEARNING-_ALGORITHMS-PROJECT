# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier

# %%
dtst=pd.read_csv("C:/Users/PARCHU/Downloads/glass.csv")

# %%
dtst
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
dtst.shape
# Out:
# (214, 10)

# %%
dtst.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
target=dtst.iloc[:,9]
target
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: Type, Length: 214, dtype: int64

# %%
features=dtst.iloc[:,0:9]
features
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 9 columns]

# %%
scalar=StandardScaler()
scalar.fit(features)
dt=scalar.transform(features)

# %%
dt
# Out:
# array([[ 0.87286765,  0.28495326,  1.25463857, ..., -0.14576634,
#         -0.35287683, -0.5864509 ],
#        [-0.24933347,  0.59181718,  0.63616803, ..., -0.79373376,
#         -0.35287683, -0.5864509 ],
#        [-0.72131806,  0.14993314,  0.60142249, ..., -0.82894938,
#         -0.35287683, -0.5864509 ],
#        ...,
#        [ 0.75404635,  1.16872135, -1.86551055, ..., -0.36410319,
#          2.95320036, -0.5864509 ],
#        [-0.61239854,  1.19327046, -1.86551055, ..., -0.33593069,
#          2.81208731, -0.5864509 ],
#        [-0.41436305,  1.00915211, -1.86551055, ..., -0.23732695,
#          3.01367739, -0.5864509 ]])

# %%
pca=PCA(n_components=2)
pca.fit(dt)
cv=pca.transform(dt)
cv
# Out:
# array([[ 1.15113957e+00, -5.29487638e-01],
#        [-5.74137172e-01, -7.59787774e-01],
#        [-9.40159722e-01, -9.29835966e-01],
#        [-1.42083283e-01, -9.61677440e-01],
#        [-3.51092291e-01, -1.09124921e+00],
#        [-2.90266583e-01, -1.32400756e+00],
#        [-2.52671444e-01, -1.11614958e+00],
#        [-1.20299466e-01, -1.22184622e+00],
#        [-2.08160308e-02, -3.21932609e-01],
#        [-2.35222894e-03, -1.06581344e+00],
#        [-3.82514937e-01, -1.38013403e+00],
#        [-1.33538675e-02, -1.10471913e+00],
#        [-3.09724390e-01, -1.42304024e+00],
#        [ 1.56521013e-01, -1.23592823e+00],
#        [-8.99566628e-02, -1.18125211e+00],
#        [-1.15255023e-01, -1.16028212e+00],
#        [ 1.73458320e-01, -1.18243967e+00],
#        [ 1.45812372e+00,  9.88413780e-02],
#        [ 5.47316267e-01, -2.95660130e-01],
#        [-3.08817022e-01, -7.63162157e-01],
#        [ 2.05673879e-01, -9.99182661e-01],
#        [ 1.21605345e+00, -4.36896108e-01],
# ...

# %%
cvv=pd.DataFrame(cv)

# %%
cvv
# Out:
#             0         1
# 0    1.151140 -0.529488
# 1   -0.574137 -0.759788
# 2   -0.940160 -0.929836
# 3   -0.142083 -0.961677
# 4   -0.351092 -1.091249
# ..        ...       ...
# 209 -2.383835  3.061677
# 210 -2.397652  3.108236
# 211 -1.680246  3.284823
# 212 -2.369748  2.756873
# 213 -2.262649  3.028592
#
# [214 rows x 2 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(cvv,target, test_size = 0.3, random_state=1)

# %%
mdl=DecisionTreeClassifier(criterion='entropy')
mdl.fit(X_train,y_train)
prdict=mdl.predict(X_test)
acc=np.mean(prdict==y_test)
acc
# Out:
# 0.5692307692307692
