# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
dtst=pd.read_csv("C:/Users/PARCHU/Downloads/concrete_data.csv")

# %%
dtst
# Out:
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse Aggregate  Fine Aggregate  Age  Strength
# 0               1040.0           676.0   28     79.99
# ...

# %%
dtst.to_string()
# Out:
# '      Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  Coarse Aggregate  Fine Aggregate  Age  Strength\n0      540.0                 0.0      0.0  162.0               2.5            1040.0           676.0   28     79.99\n1      540.0                 0.0      0.0  162.0               2.5            1055.0           676.0   28     61.89\n2      332.5               142.5      0.0  228.0               0.0             932.0           594.0  270     40.27\n3      332.5               142.5      0.0  228.0               0.0             932.0           594.0  365     41.05\n4      198.6               132.4      0.0  192.0               0.0             978.4           825.5  360     44.30\n5      266.0               114.0      0.0  228.0               0.0             932.0           670.0   90     47.03\n6      380.0                95.0      0.0  228.0               0.0             932.0           594.0  365     43.70\n7      380.0                95.0      0.0  228.0             
# ...

# %%
kme= KMeans(n_clusters=5)
model=kme.fit_predict(dtst)
print(model)
kme.cluster_centers_
stri=[]
# Out:
# [1 1 4 ... 3 3 0]

# %%
for i in range(1,11):
    km=KMeans(n_clusters=i).fit(dtst)
    km.fit(dtst)
    stri.append(km.inertia_)

# %%
stri
# Out:
# [40847591.17256507,
#  31473157.37168513,
#  24995779.959591184,
#  21989534.749324374,
#  19904080.84819134,
#  17667314.366273463,
#  16102901.363156023,
#  14580092.56957276,
#  13488838.960207291,
#  12358821.210828422]

# %%
plt.plot(range(1, 11),stri)
plt.title('Elbow method')
plt.xlabel('No of clusters')
plt.ylabel('outcome')
plt.show()

# %%
k=KMeans(n_clusters=3)
k2=k.fit_predict(dtst)
k2
# Out:
# array([1, 1, 1, ..., 2, 2, 2])
